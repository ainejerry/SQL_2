# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  ![ERD.png](attachment:ERD.png)

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %%
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
connection = "mysql+pymysql://root:1965@localhost/books"

# %%
engine = create_engine(connection)

# %%
if database_exists(connection) == False:
  create_database(connection)
else:
  print('The database already exists')
# Out:
# The database already exists

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\data.csv")
df.head()
# Out:
#    id first_name  last_name                 email
# 0   1       John        Doe          JD@books.com
# 1   2      Robin      Smith       Robin@books.com
# 2   3     Gloria  Rodriguez  grodriquez@books.com

# %%
df.to_sql('users', engine, if_exists = 'replace')
# Out:
# 3

# %%
x = pd.read_csv(r"C:\Users\DELL\Downloads\data_2.csv")
x.head()
# Out:
#    id                 title  author_id
# 0   1           The Shining          1
# 1   2                    It          1
# 2   3      The Great Gatsby          2
# 3   4  The Call of the Wild          3
# 4   5   Pride and Prejudice          4

# %%
df.to_sql('books', engine, if_exists = 'replace')
# Out:
# 3

# %%
y = pd.read_csv(r"C:\Users\DELL\Downloads\data (1).csv")
y.head()
# Out:
#    id        author_name
# 0   1       Stephen King
# 1   2  F.Scott Fitgerald
# 2   3        Jack London
# 3   4        Jane Austen
# 4   5       Mary Shelley

# %%
df.to_sql('authors', engine, if_exists = 'replace')
# Out:
# 3

# %%
z= pd.read_csv(r"C:\Users\DELL\Downloads\data (2).csv")
z.head()
# Out:
#    user_id  book_id
# 0        1        1
# 1        1        2
# 2        1        3
# 3        2        4
# 4        2        5

# %%
df.to_sql('favorites', engine, if_exists = 'replace')
# Out:
# 3

# %%
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_books
# 0         authors
# 1           books
# 2       favorites
# 3           users
